# %% [markdown]
# ---
# layout: tailwindPost
# infoGraph: simulations
# title: Interactive Simulations (Wi-Fighters)
# description: Interactive CSP lesson on simulations with live predictions and coding.
# microblog: true
# permalink: /csp/simulations/p3/lesson/
# Author: Laya Balaji, Meryl Chen
# ---

# %% [markdown]
# # 🎲 Lesson provided by Wi-Fighters
#
# {% include tailwind/simulations.html %}
