# %% [raw]
# ---
# layout: post
# title: Distributed Computing — The Slacker Network
# description: Learn how distributed systems split massive tasks across thousands of machines — the engine powering Google, Netflix, and AI.
# permalink: /lessons/slackers/distributed
# comments: true
# courses: {'csp': {'week': 25}}
# author: Slackers
# toc: true
# ---

# %% [markdown]
# # The Slacker Network: How Distributed Computing Works
#
# ---
#
# ## The Setup: One Computer vs. The Internet
#
# Every second, Google processes **~8.5 billion searches**. Netflix streams to **238 million subscribers** simultaneously. ChatGPT answers millions of requests in parallel.
#
# **Could a single computer handle that?** Not even close.
#
# The secret weapon behind all of it: **Distributed Computing** — splitting one massive job across hundreds or thousands of machines, each doing a small piece, then combining the results.
#
# <div style="font-family:'Courier New',monospace;background:#0f1117;border:1px solid #313244;border-radius:12px;padding:28px 32px;margin:20px 0;display:flex;gap:20px;align-items:stretch">
#
#   <div style="flex:1;display:flex;flex-direction:column;align-items:center;gap:14px">
#     <div style="color:#6c7086;font-size:11px;letter-spacing:2px;text-transform:uppercase">Single Machine</div>
#     <div style="background:#1e1e2e;border:2px solid #f38ba8;border-radius:10px;padding:22px 20px;text-align:center;width:100%;box-sizing:border-box;flex:1;display:flex;flex-direction:column;align-items:center;justify-content:center;gap:8px">
#       <div style="font-size:38px">🖥️</div>
#       <div style="color:#f38ba8;font-weight:bold;font-size:13px">ALL the work here</div>
#       <div style="background:#2a1515;border-radius:4px;padding:3px 12px;color:#f38ba8;font-size:11px;margin-top:2px">bottleneck!</div>
#     </div>
#     <div style="background:#2a1515;border:1px solid #f38ba8;border-radius:8px;padding:9px 28px;color:#f38ba8;font-size:14px;font-weight:bold">⏱ 4 hours</div>
#   </div>
#
#   <div style="display:flex;align-items:center;color:#45475a;font-size:20px;font-weight:bold;padding:0 8px;flex-shrink:0;align-self:center">vs.</div>
#
#   <div style="flex:1;display:flex;flex-direction:column;align-items:center;gap:14px">
#     <div style="color:#6c7086;font-size:11px;letter-spacing:2px;text-transform:uppercase">Distributed System</div>
#     <div style="display:grid;grid-template-columns:1fr 1fr;gap:8px;width:100%">
#       <div style="background:#162116;border:2px solid #a6e3a1;border-radius:8px;padding:12px 8px;text-align:center">
#         <div style="font-size:22px">💻</div>
#         <div style="color:#a6e3a1;font-size:11px;font-weight:bold;margin-top:5px">Node A</div>
#         <div style="color:#6c7086;font-size:10px;margin-top:3px">Part 1 of job</div>
#       </div>
#       <div style="background:#162116;border:2px solid #a6e3a1;border-radius:8px;padding:12px 8px;text-align:center">
#         <div style="font-size:22px">💻</div>
#         <div style="color:#a6e3a1;font-size:11px;font-weight:bold;margin-top:5px">Node B</div>
#         <div style="color:#6c7086;font-size:10px;margin-top:3px">Part 2 of job</div>
#       </div>
#       <div style="background:#162116;border:2px solid #a6e3a1;border-radius:8px;padding:12px 8px;text-align:center">
#         <div style="font-size:22px">💻</div>
#         <div style="color:#a6e3a1;font-size:11px;font-weight:bold;margin-top:5px">Node C</div>
#         <div style="color:#6c7086;font-size:10px;margin-top:3px">Part 3 of job</div>
#       </div>
#       <div style="background:#162116;border:2px solid #a6e3a1;border-radius:8px;padding:12px 8px;text-align:center">
#         <div style="font-size:22px">💻</div>
#         <div style="color:#a6e3a1;font-size:11px;font-weight:bold;margin-top:5px">Node D</div>
#         <div style="color:#6c7086;font-size:10px;margin-top:3px">Part 4 of job</div>
#       </div>
#     </div>
#     <div style="background:#162116;border:1px solid #a6e3a1;border-radius:8px;padding:9px 28px;color:#a6e3a1;font-size:14px;font-weight:bold">⏱ 1 hour ← combine results</div>
#   </div>
#
# </div>
#
# > **Key Idea:** A distributed system is a network of independent machines that *coordinate* to solve a problem that's too big for any one of them.
#
# <div style="font-family:'Courier New',monospace;background:#1e1e2e;border:1px solid #45475a;border-radius:10px;padding:18px 28px;margin:20px 0">
#   <div style="color:#f9e2af;font-size:11px;letter-spacing:2px;text-transform:uppercase;font-weight:bold;margin-bottom:12px">In this lesson</div>
#   <div style="display:grid;grid-template-columns:1fr 1fr;gap:6px 32px">
#     <div style="color:#cdd6f4;font-size:13px;padding:5px 0;border-bottom:1px solid #313244">&#8594; Splitting data across nodes (Partitioning)</div>
#     <div style="color:#cdd6f4;font-size:13px;padding:5px 0;border-bottom:1px solid #313244">&#8594; The MapReduce pattern</div>
#     <div style="color:#cdd6f4;font-size:13px;padding:5px 0">&#8594; Surviving node crashes (Fault Tolerance)</div>
#     <div style="color:#cdd6f4;font-size:13px;padding:5px 0">&#8594; Distributed vs. parallel &#8212; the key difference</div>
#   </div>
# </div>

# %% [markdown]
# ---
#
# ## The 3 Core Ideas
#
# ### 1. Partitioning — Splitting the Data
#
# Before anything runs, the data gets divided into chunks and assigned to different nodes.
#
# <div style="font-family:'Courier New',monospace;background:#0f1117;border:1px solid #313244;border-radius:12px;padding:24px 32px;margin:16px 0">
#   <div style="text-align:center;margin-bottom:16px">
#     <div style="color:#6c7086;font-size:11px;letter-spacing:2px;text-transform:uppercase;margin-bottom:10px">Input</div>
#     <div style="background:#1e1e2e;border:2px solid #89b4fa;border-radius:8px;padding:10px 24px;display:inline-block;color:#89b4fa;font-size:13px">
#       ["apple", "banana", "apple", "cherry", "banana", "apple"]
#     </div>
#   </div>
#   <div style="text-align:center;color:#6c7086;font-size:13px;margin-bottom:16px">↓ <span style="letter-spacing:2px;font-size:11px;text-transform:uppercase">Partition</span></div>
#   <div style="display:grid;grid-template-columns:1fr 1fr 1fr;gap:10px">
#     <div style="background:#162116;border:2px solid #a6e3a1;border-radius:8px;padding:14px;text-align:center">
#       <div style="color:#a6e3a1;font-weight:bold;font-size:12px;margin-bottom:8px">Node 1</div>
#       <div style="color:#cdd6f4;font-size:12px">["apple", "banana"]</div>
#     </div>
#     <div style="background:#162116;border:2px solid #a6e3a1;border-radius:8px;padding:14px;text-align:center">
#       <div style="color:#a6e3a1;font-weight:bold;font-size:12px;margin-bottom:8px">Node 2</div>
#       <div style="color:#cdd6f4;font-size:12px">["apple", "cherry"]</div>
#     </div>
#     <div style="background:#162116;border:2px solid #a6e3a1;border-radius:8px;padding:14px;text-align:center">
#       <div style="color:#a6e3a1;font-weight:bold;font-size:12px;margin-bottom:8px">Node 3</div>
#       <div style="color:#cdd6f4;font-size:12px">["banana", "apple"]</div>
#     </div>
#   </div>
# </div>
#
# ### 2. MapReduce — The Two-Step Formula
#
# Almost all distributed workloads follow this pattern:
#
# | Phase | What it does | Analogy |
# |-------|-------------|--------|
# | **Map** | Each node processes its chunk independently | Each slacker counts their own pile of words |
# | **Reduce** | One node combines all partial results | One slacker totals everyone's counts |
#
# <div style="font-family:'Courier New',monospace;background:#0f1117;border:1px solid #313244;border-radius:12px;padding:24px 32px;margin:16px 0">
#   <div style="color:#f9e2af;font-size:11px;letter-spacing:2px;text-transform:uppercase;font-weight:bold;margin-bottom:12px">MAP phase <span style="color:#6c7086;font-weight:normal">— nodes work in parallel</span></div>
#   <div style="display:grid;grid-template-columns:1fr 1fr 1fr;gap:10px;margin-bottom:20px">
#     <div style="background:#1e1e2e;border:2px solid #f9e2af;border-radius:8px;padding:14px;text-align:center">
#       <div style="color:#f9e2af;font-weight:bold;font-size:11px;margin-bottom:8px">Node 1</div>
#       <div style="color:#cdd6f4;font-size:12px">{apple:1, banana:1}</div>
#     </div>
#     <div style="background:#1e1e2e;border:2px solid #f9e2af;border-radius:8px;padding:14px;text-align:center">
#       <div style="color:#f9e2af;font-weight:bold;font-size:11px;margin-bottom:8px">Node 2</div>
#       <div style="color:#cdd6f4;font-size:12px">{apple:1, cherry:1}</div>
#     </div>
#     <div style="background:#1e1e2e;border:2px solid #f9e2af;border-radius:8px;padding:14px;text-align:center">
#       <div style="color:#f9e2af;font-weight:bold;font-size:11px;margin-bottom:8px">Node 3</div>
#       <div style="color:#cdd6f4;font-size:12px">{banana:1, apple:1}</div>
#     </div>
#   </div>
#   <div style="text-align:center;color:#6c7086;font-size:20px;margin-bottom:20px">↓</div>
#   <div style="color:#cba6f7;font-size:11px;letter-spacing:2px;text-transform:uppercase;font-weight:bold;margin-bottom:12px">REDUCE phase <span style="color:#6c7086;font-weight:normal">— combine all results</span></div>
#   <div style="background:#1e1e2e;border:2px solid #cba6f7;border-radius:8px;padding:16px;text-align:center">
#     <div style="color:#cba6f7;font-weight:bold;font-size:11px;margin-bottom:12px">Final Result</div>
#     <div style="display:flex;justify-content:center;gap:10px;flex-wrap:wrap">
#       <span style="background:#2a1f3d;border:1px solid #cba6f7;border-radius:6px;padding:6px 18px;color:#cba6f7;font-size:13px">apple: 3</span>
#       <span style="background:#2a1f3d;border:1px solid #cba6f7;border-radius:6px;padding:6px 18px;color:#cba6f7;font-size:13px">banana: 2</span>
#       <span style="background:#2a1f3d;border:1px solid #cba6f7;border-radius:6px;padding:6px 18px;color:#cba6f7;font-size:13px">cherry: 1</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# ---
#
# ### How the Coordinator Ships Data to Worker Nodes
#
# <style>
# @keyframes dc_pkg  { 0%{top:0px;opacity:1} 44%{top:66px;opacity:1} 55%{top:70px;opacity:0} 100%{top:70px;opacity:0} }
# @keyframes dc_ret  { 0%,57%{top:66px;opacity:0} 62%{top:66px;opacity:1} 92%{top:2px;opacity:1} 98%,100%{top:0;opacity:0} }
# @keyframes dc_glow { 0%,40%{box-shadow:none} 48%,60%{box-shadow:0 0 14px #89b4fa44} 70%,100%{box-shadow:none} }
# </style>
#
# <div style="font-family:'Courier New',monospace;background:#0f1117;color:#cdd6f4;padding:24px;border-radius:12px;max-width:700px;margin:16px auto;border:1px solid #313244">
#
# <h3 style="text-align:center;color:#89b4fa;margin-top:0;letter-spacing:1px">&#128230; Coordinator Distributes &amp; Collects Results</h3>
# <p style="color:#6c7086;font-size:12px;text-align:center;margin-top:-6px">The main machine sends a chunk to each worker &#8212; nodes process in parallel and send results back</p>
#
# <div style="text-align:center;margin-bottom:6px">
#   <div style="display:inline-block;background:#1e1e2e;border:2px solid #89b4fa;border-radius:8px;padding:10px 28px">
#     <div style="font-size:20px">&#128187;</div>
#     <div style="color:#89b4fa;font-weight:bold;font-size:11px;margin-top:2px;letter-spacing:1px">COORDINATOR</div>
#     <div style="color:#6c7086;font-size:9px;margin-top:2px">full dataset &#8594; split into 4 packages</div>
#   </div>
# </div>
#
# <div style="display:grid;grid-template-columns:repeat(4,1fr);gap:8px;margin-top:4px">
#
#   <div style="display:flex;flex-direction:column;align-items:center">
#     <div style="position:relative;height:85px;width:100%;display:flex;justify-content:center">
#       <div style="position:absolute;top:0;width:1px;height:100%;background:linear-gradient(to bottom,#89b4fa44,#cba6f722)"></div>
#       <div style="position:absolute;font-size:15px;animation:dc_pkg 3.6s ease-in 0s infinite">&#128230;</div>
#       <div style="position:absolute;font-size:12px;color:#cba6f7;font-weight:bold;animation:dc_ret 3.6s ease-out 0s infinite">&#10003;</div>
#     </div>
#     <div style="background:#1e1e2e;border:2px solid #313244;border-top:3px solid #cba6f7;border-radius:6px;padding:8px;width:100%;box-sizing:border-box;text-align:center;animation:dc_glow 3.6s 0s infinite">
#       <div style="color:#cba6f7;font-weight:bold;font-size:10px">NODE 1</div>
#       <div style="font-size:9px;color:#6c7086;margin-top:3px">&#8220;chunk 1&#8221;</div>
#     </div>
#   </div>
#
#   <div style="display:flex;flex-direction:column;align-items:center">
#     <div style="position:relative;height:85px;width:100%;display:flex;justify-content:center">
#       <div style="position:absolute;top:0;width:1px;height:100%;background:linear-gradient(to bottom,#89b4fa44,#fab38722)"></div>
#       <div style="position:absolute;font-size:15px;animation:dc_pkg 3.6s ease-in 0.45s infinite">&#128230;</div>
#       <div style="position:absolute;font-size:12px;color:#fab387;font-weight:bold;animation:dc_ret 3.6s ease-out 0.45s infinite">&#10003;</div>
#     </div>
#     <div style="background:#1e1e2e;border:2px solid #313244;border-top:3px solid #fab387;border-radius:6px;padding:8px;width:100%;box-sizing:border-box;text-align:center;animation:dc_glow 3.6s 0.45s infinite">
#       <div style="color:#fab387;font-weight:bold;font-size:10px">NODE 2</div>
#       <div style="font-size:9px;color:#6c7086;margin-top:3px">&#8220;chunk 2&#8221;</div>
#     </div>
#   </div>
#
#   <div style="display:flex;flex-direction:column;align-items:center">
#     <div style="position:relative;height:85px;width:100%;display:flex;justify-content:center">
#       <div style="position:absolute;top:0;width:1px;height:100%;background:linear-gradient(to bottom,#89b4fa44,#a6e3a122)"></div>
#       <div style="position:absolute;font-size:15px;animation:dc_pkg 3.6s ease-in 0.9s infinite">&#128230;</div>
#       <div style="position:absolute;font-size:12px;color:#a6e3a1;font-weight:bold;animation:dc_ret 3.6s ease-out 0.9s infinite">&#10003;</div>
#     </div>
#     <div style="background:#1e1e2e;border:2px solid #313244;border-top:3px solid #a6e3a1;border-radius:6px;padding:8px;width:100%;box-sizing:border-box;text-align:center;animation:dc_glow 3.6s 0.9s infinite">
#       <div style="color:#a6e3a1;font-weight:bold;font-size:10px">NODE 3</div>
#       <div style="font-size:9px;color:#6c7086;margin-top:3px">&#8220;chunk 3&#8221;</div>
#     </div>
#   </div>
#
#   <div style="display:flex;flex-direction:column;align-items:center">
#     <div style="position:relative;height:85px;width:100%;display:flex;justify-content:center">
#       <div style="position:absolute;top:0;width:1px;height:100%;background:linear-gradient(to bottom,#89b4fa44,#74c7ec22)"></div>
#       <div style="position:absolute;font-size:15px;animation:dc_pkg 3.6s ease-in 1.35s infinite">&#128230;</div>
#       <div style="position:absolute;font-size:12px;color:#74c7ec;font-weight:bold;animation:dc_ret 3.6s ease-out 1.35s infinite">&#10003;</div>
#     </div>
#     <div style="background:#1e1e2e;border:2px solid #313244;border-top:3px solid #74c7ec;border-radius:6px;padding:8px;width:100%;box-sizing:border-box;text-align:center;animation:dc_glow 3.6s 1.35s infinite">
#       <div style="color:#74c7ec;font-weight:bold;font-size:10px">NODE 4</div>
#       <div style="font-size:9px;color:#6c7086;margin-top:3px">&#8220;chunk 4&#8221;</div>
#     </div>
#   </div>
#
# </div>
#
# <div style="color:#6c7086;font-size:10px;text-align:center;margin-top:12px">&#128230; data package &#8595;&nbsp;&nbsp;&#124;&nbsp;&nbsp;&#10003; result &#8593; returned to coordinator</div>
# </div>

# %% [markdown]
# ---
#
# ## 3. Fault Tolerance — When Nodes Crash
#
# In a cluster of 10,000 machines, **failures are guaranteed**. Distributed systems are designed to survive them:
# - Work is **replicated** across multiple nodes
# - A **coordinator** (master node) detects failures and reassigns work
# - The job completes even when 10–20% of nodes die mid-task

# %% [markdown]
# ---
#
# ## Fault Tolerance in Action
#
# What happens when a node crashes mid-job? The coordinator detects the failure (via heartbeat timeout) and **reassigns that partition** to a healthy node. The simulation below shows this recovery in real time:

# %% [markdown]
# <style>
# @keyframes ft_hb { 0%,100%{opacity:1;transform:scale(1)} 50%{opacity:0.35;transform:scale(0.85)} }
# @keyframes ft_hb_slow { 0%,100%{opacity:1} 50%{opacity:0.2} }
# </style>
#
# <div style="font-family:'Courier New',monospace;background:#0f1117;color:#cdd6f4;padding:24px;border-radius:12px;max-width:700px;margin:16px auto;border:1px solid #313244">
#
# <h3 style="text-align:center;color:#f38ba8;margin-top:0;letter-spacing:1px">&#128148; Fault Tolerance &mdash; Crash &amp; Recovery</h3>
# <p style="color:#6c7086;font-size:12px;text-align:center;margin-top:-8px">Watch the coordinator detect a crashed node and reassign its work &mdash; with no job failure</p>
#
# <div id="ft_phase" style="text-align:center;background:#1e1e2e;border-radius:6px;padding:8px;margin-bottom:16px;color:#f9e2af;font-size:13px">
#   Click &#9654; Run to start the fault tolerance simulation
# </div>
#
# <div style="display:flex;gap:10px;margin-bottom:16px">
#   <div id="ft_node_0" style="flex:1;background:#1e1e2e;border:2px solid #313244;border-top:3px solid #a6e3a1;border-radius:8px;padding:10px;text-align:center;transition:all 0.5s">
#     <div style="color:#a6e3a1;font-size:11px;font-weight:bold">NODE 1</div>
#     <div id="ft_hb_0" style="font-size:22px;margin:6px 0;animation:ft_hb 1.2s infinite">&#128154;</div>
#     <div id="ft_ns_0" style="font-size:9px;color:#a6e3a1">running</div>
#     <div style="font-size:9px;color:#6c7086;margin-top:3px">partition 1</div>
#   </div>
#   <div id="ft_node_1" style="flex:1;background:#1e1e2e;border:2px solid #313244;border-top:3px solid #a6e3a1;border-radius:8px;padding:10px;text-align:center;transition:all 0.5s">
#     <div style="color:#a6e3a1;font-size:11px;font-weight:bold">NODE 2</div>
#     <div id="ft_hb_1" style="font-size:22px;margin:6px 0;animation:ft_hb 1.4s infinite">&#128154;</div>
#     <div id="ft_ns_1" style="font-size:9px;color:#a6e3a1">running</div>
#     <div style="font-size:9px;color:#6c7086;margin-top:3px">partition 2</div>
#   </div>
#   <div id="ft_node_2" style="flex:1;background:#1e1e2e;border:2px solid #313244;border-top:3px solid #a6e3a1;border-radius:8px;padding:10px;text-align:center;transition:all 0.5s">
#     <div style="color:#a6e3a1;font-size:11px;font-weight:bold">NODE 3</div>
#     <div id="ft_hb_2" style="font-size:22px;margin:6px 0;animation:ft_hb 1.0s infinite">&#128154;</div>
#     <div id="ft_ns_2" style="font-size:9px;color:#a6e3a1">running</div>
#     <div style="font-size:9px;color:#6c7086;margin-top:3px">partition 3</div>
#   </div>
#   <div id="ft_node_3" style="flex:1;background:#1e1e2e;border:2px solid #313244;border-top:3px solid #a6e3a1;border-radius:8px;padding:10px;text-align:center;transition:all 0.5s">
#     <div style="color:#a6e3a1;font-size:11px;font-weight:bold">NODE 4</div>
#     <div id="ft_hb_3" style="font-size:22px;margin:6px 0;animation:ft_hb 1.3s infinite">&#128154;</div>
#     <div id="ft_ns_3" style="font-size:9px;color:#a6e3a1">running</div>
#     <div style="font-size:9px;color:#6c7086;margin-top:3px">partition 4</div>
#   </div>
#   <div id="ft_spare" style="flex:1;background:#1e1e2e;border:2px dashed #313244;border-radius:8px;padding:10px;text-align:center;transition:all 0.5s;opacity:0.35">
#     <div id="ft_spare_title" style="color:#6c7086;font-size:11px;font-weight:bold">SPARE</div>
#     <div id="ft_hb_spare" style="font-size:22px;margin:6px 0">&#11036;</div>
#     <div id="ft_ns_spare" style="font-size:9px;color:#6c7086">standby</div>
#     <div style="font-size:9px;color:#6c7086;margin-top:3px">&#8212;</div>
#   </div>
# </div>
#
# <div id="ft_coord" style="background:#1e1e2e;border:2px solid #313244;border-radius:6px;padding:12px;margin-bottom:14px;transition:all 0.5s">
#   <div style="color:#89b4fa;font-size:11px;font-weight:bold;margin-bottom:8px;letter-spacing:1px">COORDINATOR (MASTER NODE)</div>
#   <div id="ft_log" style="font-size:11px;color:#6c7086;line-height:2">Monitoring heartbeats from all nodes...</div>
# </div>
#
# <div id="ft_result" style="display:none;background:#162116;border:2px solid #a6e3a1;border-radius:6px;padding:12px;margin-bottom:14px">
#   <div style="color:#a6e3a1;font-size:12px;font-weight:bold">&#9989; JOB COMPLETE &mdash; system recovered from node failure</div>
#   <div style="color:#a6e3a1;font-size:11px;margin-top:4px">All 4 partitions processed. Spare node automatically took over Node 3&rsquo;s workload. No data lost.</div>
#   <div style="color:#6c7086;font-size:10px;margin-top:6px">This is why distributed systems replicate work and use heartbeat monitoring &mdash; individual failures don&rsquo;t stop the job.</div>
# </div>
#
# <div style="text-align:center;margin-top:12px">
#   <button id="ft_btn" onclick="runFT()" style="background:#f38ba8;color:#1e1e2e;border:none;padding:9px 24px;border-radius:6px;cursor:pointer;font-family:'Courier New',monospace;font-size:13px;font-weight:bold;margin-right:8px">&#9654; Run Simulation</button>
#   <button onclick="resetFT()" style="background:#313244;color:#cdd6f4;border:none;padding:9px 24px;border-radius:6px;cursor:pointer;font-family:'Courier New',monospace;font-size:13px">&#8635; Reset</button>
# </div>
# </div>
#
# <script>
# (function(){
#   function addLog(text,color){
#     var log=document.getElementById("ft_log");
#     var span=document.createElement("span");
#     span.style.color=color||"#cdd6f4";
#     span.innerHTML="<br>"+text;
#     log.appendChild(span);
#   }
#
#   window.runFT=function(){
#     document.getElementById("ft_btn").disabled=true;
#     document.getElementById("ft_phase").textContent="⚙ All 4 nodes processing their data partitions...";
#     document.getElementById("ft_phase").style.color="#89b4fa";
#
#     // t=1.3s: Node 3 heartbeat slows
#     setTimeout(function(){
#       document.getElementById("ft_phase").textContent="⚠️ Node 3 heartbeat is irregular...";
#       document.getElementById("ft_phase").style.color="#f9e2af";
#       var hb2=document.getElementById("ft_hb_2");
#       hb2.style.animation="ft_hb_slow 2.8s infinite";
#       hb2.textContent="🖤";
#       document.getElementById("ft_ns_2").textContent="slowing...";
#       document.getElementById("ft_ns_2").style.color="#f9e2af";
#       addLog("⚠ Heartbeat from Node 3 delayed past threshold","#f9e2af");
#     },1300);
#
#     // t=2.6s: Node 3 crashes
#     setTimeout(function(){
#       document.getElementById("ft_phase").textContent="💀 NODE 3 CRASHED — heartbeat timeout!";
#       document.getElementById("ft_phase").style.color="#f38ba8";
#       var n2=document.getElementById("ft_node_2");
#       n2.style.background="#2a1515";
#       n2.style.borderColor="#f38ba8";
#       n2.style.borderTop="3px solid #f38ba8";
#       var hb2=document.getElementById("ft_hb_2");
#       hb2.textContent="💥";
#       hb2.style.animation="none";
#       document.getElementById("ft_ns_2").textContent="CRASHED";
#       document.getElementById("ft_ns_2").style.color="#f38ba8";
#       document.getElementById("ft_coord").style.borderColor="#f38ba8";
#       addLog("✗ Node 3 HEARTBEAT TIMEOUT — connection lost","#f38ba8");
#     },2600);
#
#     // t=3.4s: Coordinator detects and plans reassignment
#     setTimeout(function(){
#       document.getElementById("ft_coord").style.borderColor="#f9e2af";
#       document.getElementById("ft_phase").textContent="🔄 Coordinator reassigning Node 3’s partition to spare node...";
#       document.getElementById("ft_phase").style.color="#f9e2af";
#       addLog("→ Coordinator: marking Node 3 as FAILED","#f9e2af");
#       addLog("→ Partition 3 unfinished — searching for spare node...","#f9e2af");
#     },3400);
#
#     // t=4.4s: Spare node activates
#     setTimeout(function(){
#       var spare=document.getElementById("ft_spare");
#       spare.style.opacity="1";
#       spare.style.borderStyle="solid";
#       spare.style.borderColor="#a6e3a1";
#       spare.style.borderTop="3px solid #a6e3a1";
#       spare.style.background="#162116";
#       document.getElementById("ft_spare_title").textContent="SPARE ★";
#       document.getElementById("ft_spare_title").style.color="#a6e3a1";
#       var hbs=document.getElementById("ft_hb_spare");
#       hbs.textContent="💚";
#       hbs.style.animation="ft_hb 1.1s infinite";
#       document.getElementById("ft_ns_spare").textContent="running";
#       document.getElementById("ft_ns_spare").style.color="#a6e3a1";
#       document.getElementById("ft_coord").style.borderColor="#a6e3a1";
#       document.getElementById("ft_phase").textContent="✅ Spare node activated — processing partition 3...";
#       document.getElementById("ft_phase").style.color="#a6e3a1";
#       addLog("★ Spare node activated — assigned partition 3","#a6e3a1");
#     },4400);
#
#     // t=5.8s: Job completes
#     setTimeout(function(){
#       document.getElementById("ft_phase").textContent="🎉 JOB COMPLETE — recovered from crash, no data lost!";
#       document.getElementById("ft_phase").style.color="#a6e3a1";
#       addLog("✓ All 4 partitions complete. Job succeeded despite node failure.","#a6e3a1");
#       document.getElementById("ft_result").style.display="block";
#       document.getElementById("ft_btn").disabled=false;
#     },5800);
#   };
#
#   window.resetFT=function(){
#     document.getElementById("ft_btn").disabled=false;
#     document.getElementById("ft_phase").textContent="Click ▶ Run to start the fault tolerance simulation";
#     document.getElementById("ft_phase").style.color="#f9e2af";
#     document.getElementById("ft_result").style.display="none";
#     var coord=document.getElementById("ft_coord");
#     coord.style.borderColor="#313244";
#     document.getElementById("ft_log").innerHTML="Monitoring heartbeats from all nodes...";
#     var anims=["ft_hb 1.2s infinite","ft_hb 1.4s infinite","ft_hb 1.0s infinite","ft_hb 1.3s infinite"];
#     for(var i=0;i<4;i++){
#       var nd=document.getElementById("ft_node_"+i);
#       nd.style.background="#1e1e2e";
#       nd.style.borderColor="#313244";
#       nd.style.borderTop="3px solid #a6e3a1";
#       var hb=document.getElementById("ft_hb_"+i);
#       hb.textContent="💚";
#       hb.style.animation=anims[i];
#       document.getElementById("ft_ns_"+i).textContent="running";
#       document.getElementById("ft_ns_"+i).style.color="#a6e3a1";
#     }
#     var spare=document.getElementById("ft_spare");
#     spare.style.opacity="0.35";
#     spare.style.borderStyle="dashed";
#     spare.style.borderColor="#313244";
#     spare.style.borderTop="";
#     spare.style.background="#1e1e2e";
#     document.getElementById("ft_spare_title").textContent="SPARE";
#     document.getElementById("ft_spare_title").style.color="#6c7086";
#     var hbs=document.getElementById("ft_hb_spare");
#     hbs.textContent="⬜";
#     hbs.style.animation="none";
#     document.getElementById("ft_ns_spare").textContent="standby";
#     document.getElementById("ft_ns_spare").style.color="#6c7086";
#   };
# })();
# </script>

# %% [markdown]
# ---
#
# ## Distributed vs. Parallel — Don't Mix Them Up
#
# <div style="font-family:'Courier New',monospace;background:#0f1117;border:1px solid #313244;border-radius:12px;padding:24px 32px;margin:16px 0;display:grid;grid-template-columns:1fr 1fr;gap:20px">
#   <div>
#     <div style="color:#89b4fa;font-size:13px;font-weight:bold;letter-spacing:1px;padding-bottom:10px;border-bottom:2px solid #89b4fa;margin-bottom:12px">Parallel Computing</div>
#     <div style="display:flex;flex-direction:column;gap:8px">
#       <div style="background:#1e1e2e;border-left:3px solid #89b4fa;border-radius:0 6px 6px 0;padding:9px 16px;color:#cdd6f4;font-size:13px">Multiple cores / threads</div>
#       <div style="background:#1e1e2e;border-left:3px solid #89b4fa;border-radius:0 6px 6px 0;padding:9px 16px;color:#cdd6f4;font-size:13px">Shared memory</div>
#       <div style="background:#1e1e2e;border-left:3px solid #89b4fa;border-radius:0 6px 6px 0;padding:9px 16px;color:#cdd6f4;font-size:13px">Fast, tight coordination</div>
#       <div style="background:#1e1e2e;border-left:3px solid #89b4fa;border-radius:0 6px 6px 0;padding:9px 16px;color:#cdd6f4;font-size:13px">Your laptop's 8 cores</div>
#     </div>
#   </div>
#   <div>
#     <div style="color:#a6e3a1;font-size:13px;font-weight:bold;letter-spacing:1px;padding-bottom:10px;border-bottom:2px solid #a6e3a1;margin-bottom:12px">Distributed Computing</div>
#     <div style="display:flex;flex-direction:column;gap:8px">
#       <div style="background:#1e1e2e;border-left:3px solid #a6e3a1;border-radius:0 6px 6px 0;padding:9px 16px;color:#cdd6f4;font-size:13px">Multiple machines</div>
#       <div style="background:#1e1e2e;border-left:3px solid #a6e3a1;border-radius:0 6px 6px 0;padding:9px 16px;color:#cdd6f4;font-size:13px">Separate memory + network</div>
#       <div style="background:#1e1e2e;border-left:3px solid #a6e3a1;border-radius:0 6px 6px 0;padding:9px 16px;color:#cdd6f4;font-size:13px">Slower, must survive failures</div>
#       <div style="background:#1e1e2e;border-left:3px solid #a6e3a1;border-radius:0 6px 6px 0;padding:9px 16px;color:#cdd6f4;font-size:13px">Google's 10,000 servers</div>
#     </div>
#   </div>
# </div>
#
# <div style="font-family:'Courier New',monospace;background:#1e1e2e;border-left:4px solid #f9e2af;border-radius:0 8px 8px 0;padding:14px 20px;margin:16px 0">
#   <div style="color:#f9e2af;font-size:11px;letter-spacing:2px;text-transform:uppercase;font-weight:bold;margin-bottom:6px">Key difference</div>
#   <div style="color:#cdd6f4;font-size:13px;line-height:1.7">Both split work — but distributed systems must also handle <strong style="color:#f9e2af">network delays</strong>, <strong style="color:#f9e2af">partial failures</strong>, and <strong style="color:#f9e2af">no shared state</strong>. That's what makes them harder to build than parallel programs.</div>
# </div>
#
# ---
#
# ## Where You've Already Used This
#
# | System | How it's distributed |
# |--------|---------------------|
# | **Google Search** | Your query hits ~1000 machines simultaneously, results merged in <100ms |
# | **Netflix** | Video chunks served from the nearest of 10,000+ CDN nodes worldwide |
# | **ChatGPT** | Inference split across hundreds of GPUs per request |

# %% [markdown]
# ---
#
# ## College Board Practice Questions
#
# ### What to Expect on the Exam
#
# The AP CSP exam tests distributed computing under **Big Idea 4: Computing Systems and Networks**. Questions typically ask you to:
#
# - **Identify why** distributed computing is used (scale, speed, problems too large for one machine)
# - **Calculate or reason about speedup** — how much faster a distributed system finishes compared to one machine
# - **Recognize limitations** — distributed computing doesn't always produce a perfect speedup due to coordination overhead and tasks that can't be split
# - **Apply fault tolerance** — what a system does when a node fails
# - **Pick the best tool for the job** — scenarios where you decide if distributed computing helps
#
# Speedup is calculated as:
#
# > **Speedup = Time on 1 machine ÷ Time on N machines**
#
# For example, if a task takes 400 seconds alone but 100 seconds across 4 machines, the speedup is **4×**. Perfect speedup is rare — coordination overhead and non-distributable portions of the task reduce the real gain.
#
# ---
#
# <style>
# .dc-mcq { font-family: 'Courier New', monospace; background: #0f1117; color: #cdd6f4; padding: 28px 36px; border-radius: 12px; width: 100%; margin: 20px 0; border: 1px solid #313244; box-sizing: border-box; }
# .dc-mcq h4 { color: #89b4fa; margin-top: 0; letter-spacing: 1px; font-size: 16px; }
# .dc-mcq .question { color: #cdd6f4; font-size: 15px; line-height: 1.8; margin-bottom: 18px; }
# .dc-opt { display: block; width: 100%; text-align: left; background: #1e1e2e; border: 2px solid #313244; color: #cdd6f4; padding: 13px 20px; border-radius: 8px; margin-bottom: 10px; cursor: pointer; font-family: 'Courier New', monospace; font-size: 14px; line-height: 1.6; transition: border-color 0.2s, background 0.2s; box-sizing: border-box; }
# .dc-opt:hover:not(:disabled) { border-color: #89b4fa; background: #181825; }
# .dc-opt.correct { border-color: #a6e3a1 !important; background: #162116 !important; color: #a6e3a1 !important; }
# .dc-opt.wrong   { border-color: #f38ba8 !important; background: #2a1515 !important; color: #f38ba8 !important; }
# .dc-opt:disabled { cursor: default; }
# .dc-feedback { font-size: 14px; border-radius: 6px; padding: 14px 18px; margin-top: 12px; line-height: 1.8; display: none; }
# .dc-feedback.correct { background: #162116; border: 1px solid #a6e3a1; color: #a6e3a1; }
# .dc-feedback.wrong   { background: #2a1515; border: 1px solid #f38ba8; color: #f38ba8; }
# .dc-reset { background: #313244; color: #cdd6f4; border: none; padding: 8px 20px; border-radius: 6px; cursor: pointer; font-family: 'Courier New', monospace; font-size: 13px; margin-top: 12px; }
# .dc-reset:hover { background: #45475a; }
# </style>
#
# <div class="dc-mcq">
#   <h4>Q1 — Speedup Calculation</h4>
#   <p class="question">A research team needs to analyze a dataset so large that a single computer would take <strong>200 hours</strong> to process it. They distribute the task across 50 identical machines. Assuming the task splits evenly and coordination overhead is negligible, approximately how long will it take?</p>
#   <button class="dc-opt" onclick="dcCheck('q1',this,'wrong','q1fb')">A) 200 hours — distributed computing does not change total processing time</button>
#   <button class="dc-opt" onclick="dcCheck('q1',this,'wrong','q1fb')">B) 100 hours — each machine handles half the work</button>
#   <button class="dc-opt" onclick="dcCheck('q1',this,'correct','q1fb')">C) 4 hours — each machine handles 1/50th of the work</button>
#   <button class="dc-opt" onclick="dcCheck('q1',this,'wrong','q1fb')">D) Less than 1 minute — distributed computing eliminates processing time entirely</button>
#   <div id="q1fb" class="dc-feedback"></div>
#   <button class="dc-reset" onclick="dcReset('q1','q1fb')">↺ Reset</button>
# </div>
#
# <div class="dc-mcq">
#   <h4>Q2 — Fault Tolerance</h4>
#   <p class="question">A company runs a distributed system across 20 nodes to handle customer orders. <strong>Node 12 crashes</strong> mid-operation. Which of the following describes the behavior of a <strong>fault-tolerant</strong> distributed system?</p>
#   <button class="dc-opt" onclick="dcCheck('q2',this,'wrong','q2fb')">A) All 20 nodes shut down and the entire operation must restart</button>
#   <button class="dc-opt" onclick="dcCheck('q2',this,'correct','q2fb')">B) The coordinator detects the failure via a missed heartbeat and reassigns Node 12's work to another available node</button>
#   <button class="dc-opt" onclick="dcCheck('q2',this,'wrong','q2fb')">C) The operation completes, but all data processed by Node 12 is permanently lost</button>
#   <button class="dc-opt" onclick="dcCheck('q2',this,'wrong','q2fb')">D) The system pauses until Node 12 is manually repaired</button>
#   <div id="q2fb" class="dc-feedback"></div>
#   <button class="dc-reset" onclick="dcReset('q2','q2fb')">↺ Reset</button>
# </div>
#
# <div class="dc-mcq">
#   <h4>Q3 — Core Concept</h4>
#   <p class="question">Which of the following statements about distributed computing is <strong>true</strong>?</p>
#   <button class="dc-opt" onclick="dcCheck('q3',this,'wrong','q3fb')">A) Adding more machines always produces a proportional speedup</button>
#   <button class="dc-opt" onclick="dcCheck('q3',this,'wrong','q3fb')">B) Distributed computing is only useful when a single machine is broken</button>
#   <button class="dc-opt" onclick="dcCheck('q3',this,'correct','q3fb')">C) Distributed computing allows problems that are too large or slow for one machine to be solved by splitting the work across many machines</button>
#   <button class="dc-opt" onclick="dcCheck('q3',this,'wrong','q3fb')">D) All tasks must be completed sequentially before results can be combined in a distributed system</button>
#   <div id="q3fb" class="dc-feedback"></div>
#   <button class="dc-reset" onclick="dcReset('q3','q3fb')">↺ Reset</button>
# </div>
#
# <script>
# (function(){
#   var explanations = {
#     q1: {
#       correct: "Correct! 200 hours ÷ 50 machines = 4 hours. This is the speedup formula: time on 1 machine divided by number of machines. Distributed computing doesn't eliminate work — it splits it so machines run simultaneously, reducing wall-clock time proportionally.",
#       wrong:   "Not quite. Use the speedup formula: 200 hours ÷ 50 machines = 4 hours (choice C). Each of the 50 machines works on 1/50th of the data at the same time."
#     },
#     q2: {
#       correct: "Correct! Fault-tolerant distributed systems use heartbeat monitoring — each node sends regular signals to the coordinator. When a heartbeat times out, the coordinator marks that node as failed and reassigns its workload automatically, without data loss.",
#       wrong:   "Not quite. A fault-tolerant system (choice B) uses heartbeat monitoring to detect failures and automatically reassigns work. The system does NOT stop, lose data, or wait for manual repair."
#     },
#     q3: {
#       correct: "Correct! This is the core definition the AP CSP exam tests. Distributed computing's value is handling scale — tasks too large to store, too slow to process, or too critical to risk on one machine.",
#       wrong:   "Not quite. Choice C is the correct definition. A is false — coordination overhead limits real-world speedup. B is false — it's about scale, not broken machines. D is false — the whole point is that work runs simultaneously across nodes."
#     }
#   };
#
#   window.dcCheck = function(qid, btn, result, fbid) {
#     var container = btn.parentElement;
#     var btns = container.querySelectorAll('.dc-opt');
#     btns.forEach(function(b){ b.disabled = true; });
#     btn.classList.add(result);
#     var fb = document.getElementById(fbid);
#     fb.className = 'dc-feedback ' + result;
#     fb.textContent = (result === 'correct' ? '✓ ' : '✗ ') + explanations[qid][result];
#     fb.style.display = 'block';
#   };
#
#   window.dcReset = function(qid, fbid) {
#     var fb = document.getElementById(fbid);
#     fb.style.display = 'none';
#     fb.className = 'dc-feedback';
#     fb.textContent = '';
#     var container = fb.parentElement;
#     var btns = container.querySelectorAll('.dc-opt');
#     btns.forEach(function(b){
#       b.disabled = false;
#       b.classList.remove('correct','wrong');
#     });
#   };
# })();
# </script>
