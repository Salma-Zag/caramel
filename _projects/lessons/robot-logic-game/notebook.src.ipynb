# %% [markdown]
# ---
# layout: post
# title: Robot Logic Game
# description: Six levels — sequence, iteration, and selection — solved with block pseudocode.
# permalink: /robot-logic-game
# hide: false
# toc: false
# author: T3 Lessons
# ---

# %% [markdown]
# <div class="rlg-hero">
#   <h1>Robot Logic Game</h1>
#   <p class="rlg-tagline">Six levels. One robot. Six blocks. Reach the goal — then make your program shorter.</p>
# </div>
#
# <div class="rlg-blockgrid">
#   <div class="rlg-block" style="--c:#4f9dff">Forward</div>
#   <div class="rlg-block" style="--c:#5ad1d1">Backward</div>
#   <div class="rlg-block" style="--c:#ffb347">Turn Left</div>
#   <div class="rlg-block" style="--c:#ffb347">Turn Right</div>
#   <div class="rlg-block" style="--c:#b78cff">Repeat N</div>
#   <div class="rlg-block" style="--c:#e98acc">If Can Move</div>
# </div>

# %% [markdown]
# <style>
# .rlg-hero {
#   background: linear-gradient(135deg, #1c2238 0%, #2a1f4a 50%, #1c2238 100%);
#   border: 1px solid #3a4466;
#   border-radius: 14px;
#   padding: 36px 32px;
#   margin: 24px 0 18px 0;
#   color: #f2f2f2;
#   font-family: system-ui, -apple-system, Segoe UI, sans-serif;
#   box-shadow: 0 12px 40px rgba(0,0,0,0.35);
# }
# .rlg-hero h1 {
#   margin: 0 0 8px 0;
#   font-size: 36px;
#   font-weight: 800;
#   background: linear-gradient(90deg, #4f9dff, #b78cff, #e98acc);
#   -webkit-background-clip: text;
#   background-clip: text;
#   color: transparent;
#   letter-spacing: -0.02em;
# }
# .rlg-hero .rlg-tagline {
#   margin: 0;
#   font-size: 17px;
#   opacity: 0.85;
#   color: #f2f2f2;
# }
# .rlg-blockgrid {
#   display: grid;
#   grid-template-columns: repeat(auto-fit, minmax(140px, 1fr));
#   gap: 10px;
#   margin: 0 0 28px 0;
# }
# .rlg-blockgrid .rlg-block {
#   background: var(--c);
#   color: #0f1524;
#   font-weight: 700;
#   font-size: 14px;
#   padding: 14px 16px;
#   border-radius: 8px;
#   text-align: center;
#   font-family: system-ui, -apple-system, Segoe UI, sans-serif;
#   box-shadow: 0 2px 6px rgba(0,0,0,0.25);
# }
# .rlg-launcher {
#   background: linear-gradient(135deg, #1d2230 0%, #232a44 100%);
#   border: 1px solid #2c3347;
#   border-radius: 12px;
#   padding: 22px 26px;
#   margin: 22px 0;
#   color: #f2f2f2;
#   font-family: system-ui, -apple-system, Segoe UI, sans-serif;
#   display: flex;
#   align-items: center;
#   gap: 22px;
#   box-shadow: 0 4px 14px rgba(0,0,0,0.25);
#   transition: transform 180ms, box-shadow 180ms, border-color 180ms;
# }
# .rlg-launcher:hover {
#   transform: translateY(-2px);
#   box-shadow: 0 10px 28px rgba(0,0,0,0.4);
#   border-color: #4f9dff;
# }
# .rlg-launcher .rlg-num {
#   flex-shrink: 0;
#   width: 56px;
#   height: 56px;
#   border-radius: 14px;
#   background: linear-gradient(135deg, #4f9dff, #b78cff);
#   display: flex;
#   align-items: center;
#   justify-content: center;
#   font-size: 26px;
#   font-weight: 800;
#   color: #0f1524;
#   box-shadow: 0 4px 14px rgba(79,157,255,0.35);
# }
# .rlg-launcher .rlg-info { flex: 1; min-width: 0; }
# .rlg-launcher .rlg-title { font-weight: 700; font-size: 18px; margin: 0 0 4px 0; color: #fff; }
# .rlg-launcher .rlg-blurb { font-size: 14px; opacity: 0.7; margin: 0 0 10px 0; color: #e8eef8; line-height: 1.4; }
# .rlg-launcher .rlg-meta {
#   display: flex;
#   align-items: center;
#   gap: 14px;
#   flex-wrap: wrap;
# }
# .rlg-launcher .rlg-stars { font-size: 18px; letter-spacing: 3px; }
# .rlg-launcher .rlg-stars .filled { color: #ffd84a; text-shadow: 0 0 8px rgba(255,216,74,0.4); }
# .rlg-launcher .rlg-stars .empty { color: #3a4466; }
# .rlg-launcher .rlg-thresh {
#   font-size: 12px;
#   opacity: 0.55;
#   color: #e8eef8;
#   font-variant-numeric: tabular-nums;
# }
# .rlg-launcher .rlg-launch-btn {
#   flex-shrink: 0;
#   background: linear-gradient(135deg, #2ea66a, #38c07c);
#   color: #fff;
#   border: none;
#   cursor: pointer;
#   padding: 14px 24px;
#   font-weight: 700;
#   font-size: 15px;
#   border-radius: 10px;
#   display: inline-flex;
#   align-items: center;
#   gap: 8px;
#   box-shadow: 0 4px 14px rgba(46,166,106,0.35);
#   transition: transform 140ms, box-shadow 140ms;
# }
# .rlg-launcher .rlg-launch-btn:hover {
#   transform: translateX(2px);
#   box-shadow: 0 6px 20px rgba(46,166,106,0.5);
# }
# .rlg-launcher .rlg-launch-btn:focus { outline: 2px solid #4f9dff; outline-offset: 3px; }
# .rlg-launcher .rlg-arrow { transition: transform 200ms; }
# .rlg-launcher:hover .rlg-arrow { transform: translateX(3px); }
# .rlg-section {
#   margin-top: 36px;
#   padding-top: 18px;
#   border-top: 1px solid #2c3347;
#   color: #f2f2f2;
#   font-family: system-ui, -apple-system, Segoe UI, sans-serif;
# }
# .rlg-section h2 {
#   font-size: 22px;
#   margin: 0 0 6px 0;
#   color: #fff;
# }
# .rlg-section p { margin: 0; opacity: 0.75; line-height: 1.5; }
# .rlg-section .rlg-hint { font-size: 13px; opacity: 0.55; margin-top: 6px; font-style: italic; }
# @media (max-width: 600px) {
#   .rlg-launcher { flex-direction: column; align-items: stretch; }
#   .rlg-launcher .rlg-launch-btn { width: 100%; justify-content: center; }
# }
# </style>
#
# <script type="module">
# import { mountLevel } from '/assets/js/projects/robot-logic-game/levels/RobotLogicLevel.js';
# import { getLevelStars } from '/assets/js/projects/robot-logic-game/levels/progress.js';
#
# function renderStars(card) {
#   const id = parseInt(card.dataset.rlgLevel, 10);
#   const stars = getLevelStars(id);
#   const wrap = card.querySelector('.rlg-stars');
#   if (!wrap) return;
#   wrap.innerHTML = '';
#   for (let i = 0; i < 3; i++) {
#     const s = document.createElement('span');
#     s.textContent = '★';
#     s.className = i < stars ? 'filled' : 'empty';
#     wrap.appendChild(s);
#   }
# }
#
# function refreshAll() {
#   document.querySelectorAll('[data-rlg-level]').forEach(renderStars);
# }
#
# document.addEventListener('click', (e) => {
#   const btn = e.target.closest('.rlg-launch-btn');
#   if (!btn) return;
#   const card = btn.closest('[data-rlg-level]');
#   if (!card) return;
#   const id = parseInt(card.dataset.rlgLevel, 10);
#   if (!Number.isFinite(id)) return;
#   mountLevel({ levelId: id, onClose: refreshAll });
# });
#
# if (document.readyState === 'loading') {
#   document.addEventListener('DOMContentLoaded', refreshAll);
# } else {
#   refreshAll();
# }
# </script>

# %% [markdown]
# <div class="rlg-section">
#   <h2>1 · Sequence</h2>
#   <p>Stack instructions. The robot does them in order.</p>
# </div>

# %% [markdown]
# <div class="rlg-launcher" data-rlg-level="1">
#   <div class="rlg-num">1</div>
#   <div class="rlg-info">
#     <p class="rlg-title">First Steps</p>
#     <p class="rlg-blurb">7×7 grid, no walls. Reach the green tile.</p>
#     <div class="rlg-meta">
#       <span class="rlg-stars"></span>
#       <span class="rlg-thresh">★★★ ≤ 5 blocks · ★★ ≤ 8</span>
#     </div>
#   </div>
#   <button class="rlg-launch-btn" type="button">Play <span class="rlg-arrow">→</span></button>
# </div>

# %% [markdown]
# <div class="rlg-section">
#   <h2>2 · Detour</h2>
#   <p>Same instructions. A wall is in the way.</p>
# </div>

# %% [markdown]
# <div class="rlg-launcher" data-rlg-level="2">
#   <div class="rlg-num">2</div>
#   <div class="rlg-info">
#     <p class="rlg-title">Around the Wall</p>
#     <p class="rlg-blurb">Plan a route — the direct path is blocked.</p>
#     <div class="rlg-meta">
#       <span class="rlg-stars"></span>
#       <span class="rlg-thresh">★★★ ≤ 11 blocks · ★★ ≤ 14</span>
#     </div>
#   </div>
#   <button class="rlg-launch-btn" type="button">Play <span class="rlg-arrow">→</span></button>
# </div>

# %% [markdown]
# <div class="rlg-section">
#   <h2>3 · Iteration</h2>
#   <p>The same block, repeated, fits inside one <code>Repeat N times</code>.</p>
# </div>

# %% [markdown]
# <div class="rlg-launcher" data-rlg-level="3">
#   <div class="rlg-num">3</div>
#   <div class="rlg-info">
#     <p class="rlg-title">The Long Way</p>
#     <p class="rlg-blurb">A longer detour. Use Repeat to keep your program short.</p>
#     <div class="rlg-meta">
#       <span class="rlg-stars"></span>
#       <span class="rlg-thresh">★★★ ≤ 11 blocks · ★★ ≤ 17</span>
#     </div>
#   </div>
#   <button class="rlg-launch-btn" type="button">Play <span class="rlg-arrow">→</span></button>
# </div>

# %% [markdown]
# <div class="rlg-section">
#   <h2>4 · A new block</h2>
#   <p>Sometimes the goal is behind you. <code>Move Backward</code> appears.</p>
# </div>

# %% [markdown]
# <div class="rlg-launcher" data-rlg-level="4">
#   <div class="rlg-num">4</div>
#   <div class="rlg-info">
#     <p class="rlg-title">Reverse Course</p>
#     <p class="rlg-blurb">Three stars in two blocks. Find them.</p>
#     <div class="rlg-meta">
#       <span class="rlg-stars"></span>
#       <span class="rlg-thresh">★★★ ≤ 2 blocks · ★★ ≤ 4</span>
#     </div>
#   </div>
#   <button class="rlg-launch-btn" type="button">Play <span class="rlg-arrow">→</span></button>
# </div>

# %% [markdown]
# <div class="rlg-section">
#   <h2>5 · Patterns</h2>
#   <p>A small repeating pattern, repeated. Reach for a <code>Repeat</code> inside a <code>Repeat</code>.</p>
# </div>

# %% [markdown]
# <div class="rlg-launcher" data-rlg-level="5">
#   <div class="rlg-num">5</div>
#   <div class="rlg-info">
#     <p class="rlg-title">Corridor Maze</p>
#     <p class="rlg-blurb">Zigzag through stacked corridors.</p>
#     <div class="rlg-meta">
#       <span class="rlg-stars"></span>
#       <span class="rlg-thresh">★★★ ≤ 13 blocks · ★★ ≤ 20</span>
#     </div>
#   </div>
#   <button class="rlg-launch-btn" type="button">Play <span class="rlg-arrow">→</span></button>
# </div>

# %% [markdown]
# <div class="rlg-section">
#   <h2>6 · Selection</h2>
#   <p><code>If Can Move Forward</code> arrives. The robot can now decide.</p>
#   <p class="rlg-hint">Five blocks is enough. The robot doesn't need to know how long the corridors are.</p>
# </div>

# %% [markdown]
# <div class="rlg-launcher" data-rlg-level="6">
#   <div class="rlg-num">6</div>
#   <div class="rlg-info">
#     <p class="rlg-title">Right-Hand Spiral</p>
#     <p class="rlg-blurb">One nested loop. Walk-then-turn until the goal.</p>
#     <div class="rlg-meta">
#       <span class="rlg-stars"></span>
#       <span class="rlg-thresh">★★★ ≤ 5 blocks · ★★ ≤ 9</span>
#     </div>
#   </div>
#   <button class="rlg-launch-btn" type="button">Play <span class="rlg-arrow">→</span></button>
# </div>

# %% [markdown]
# <div class="rlg-section">
#   <h2>Challenges</h2>
#   <p>1. Earn three stars on every level.<br>
#   2. Solve Level 6 without <code>If Can Move Forward</code>. Count the extra blocks.<br>
#   3. Pick any three-star solve and try to remove one more block.<br>
#   4. Add a level: open <code>_projects/robot-logic-game/levels/levelConfigs.js</code> and define one.</p>
# </div>
