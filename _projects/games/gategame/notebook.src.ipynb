# %% [raw]
# ---
# layout: post
# title: Gate Game
# description: Dont let Slime Boy Melt
# permalink: /gategame
# hide: false
# toc: false
# author: Kashyap Tubati
# ---

# %%
# %%js
#
# // GAME_RUNNER: CSSE Zone Game | hide_edit: true, width: 100%, height: 500px
#
# import GameControl from '@assets/js/GameEnginev1.1/essentials/GameControl.js';
# import GameLevelCannonball from '@assets/js/projects/gategame/levels/GameLevelCannonball.js';
# import GameLevelEscaperoom from '@assets/js/projects/gategame/levels/GameLevelEscaperoom.js';
# import GameLevelZonecatch from '@assets/js/projects/gategame/levels/GameLevelZonecatch.js';
#
# export const gameLevelClasses = [GameLevelCannonball, GameLevelEscaperoom, GameLevelZonecatch];
# export { GameControl };

# %% [markdown]
# **Open Non Bugged Fullscreen Version**
#
# [https://gates.opencodingsociety.com/gamify/gategamev2](https://gates.opencodingsociety.com/gamify/gategamev2)

# %% [raw]
# <link href="https://fonts.googleapis.com/css2?family=Orbitron:wght@700;900&family=JetBrains+Mono:wght@400;500;700&display=swap" rel="stylesheet">
# <style>
# :root {
#   --bg: #06080f;
#   --surface: #0b0d18;
#   --border: #1a2040;
#   --cyan: #4dc8ff;
#   --green: #4dff90;
#   --purple: #c792ea;
#   --yellow: #ffcc4d;
#   --orange: #f78c6c;
#   --dim: #4a5070;
#   --text: #c0c8f0;
#   --mono: 'JetBrains Mono', monospace;
#   --head: 'Orbitron', monospace;
# }
# .garch {
#   font-family: var(--mono);
#   background: var(--bg);
#   color: var(--text);
#   padding: 0;
#   margin: 1.5rem 0;
# }
# /* ── shared section shell ── */
# .gs {
#   background: #08091200;
#   border: 1px solid var(--border);
#   border-radius: 12px;
#   padding: 28px;
#   margin-bottom: 1.5rem;
#   overflow: hidden;
# }
# .gs-title {
#   font-family: var(--head);
#   font-size: 17px;
#   font-weight: 700;
#   color: #fff;
#   letter-spacing: 1px;
#   margin: 0 0 6px;
# }
# .gs-title span { color: var(--cyan); }
# .gs-sub { font-size: 11px; color: var(--dim); margin: 0 0 24px; letter-spacing: 1px; }
#
# /* ── SECTION 1: Architecture pipeline ── */
# .pipe {
#   display: flex;
#   align-items: stretch;
#   gap: 0;
#   margin-bottom: 24px;
#   overflow-x: auto;
# }
# .pipe-node {
#   flex: 1;
#   min-width: 130px;
#   background: rgba(255,255,255,0.02);
#   border: 1px solid var(--border);
#   border-radius: 8px;
#   padding: 14px 10px;
#   text-align: center;
#   cursor: pointer;
#   transition: all 0.2s;
#   position: relative;
# }
# .pipe-node:not(:last-child)::after {
#   content: '→';
#   position: absolute;
#   right: -18px;
#   top: 50%;
#   transform: translateY(-50%);
#   color: #1a5aee;
#   font-size: 18px;
#   z-index: 1;
# }
# .pipe-node:hover, .pipe-node.active {
#   border-color: var(--cyan);
#   background: rgba(77,200,255,0.07);
#   transform: translateY(-2px);
#   box-shadow: 0 6px 20px rgba(77,200,255,0.12);
# }
# .pipe-icon { font-size: 26px; margin-bottom: 8px; }
# .pipe-label { font-size: 11px; font-weight: 700; color: #fff; margin-bottom: 4px; }
# .pipe-file { font-size: 10px; color: var(--dim); }
# .pipe-detail {
#   background: rgba(0,0,0,0.5);
#   border: 1px solid #1a5aee;
#   border-radius: 8px;
#   padding: 16px 20px;
#   font-size: 12px;
#   line-height: 1.8;
#   color: var(--text);
#   min-height: 80px;
#   transition: all 0.2s;
# }
# .pipe-detail strong { color: var(--cyan); }
# .pipe-detail code { color: var(--green); font-size: 11px; }
#
# /* ── SECTION 2: Game loop ── */
# .loop-wrap {
#   display: grid;
#   grid-template-columns: 200px 1fr;
#   gap: 20px;
# }
# .loop-steps {
#   display: flex;
#   flex-direction: column;
#   gap: 4px;
# }
# .loop-step {
#   display: flex;
#   align-items: center;
#   gap: 10px;
#   padding: 10px 12px;
#   border-radius: 6px;
#   border: 1px solid var(--border);
#   cursor: pointer;
#   transition: all 0.2s;
#   font-size: 12px;
# }
# .loop-step:hover, .loop-step.active {
#   border-color: var(--green);
#   background: rgba(77,255,144,0.07);
# }
# .loop-step-dot {
#   width: 8px; height: 8px;
#   border-radius: 50%;
#   background: var(--border);
#   flex-shrink: 0;
#   transition: background 0.2s;
# }
# .loop-step.active .loop-step-dot { background: var(--green); box-shadow: 0 0 6px var(--green); }
# .loop-anim {
#   background: #010306;
#   border: 1px solid var(--border);
#   border-radius: 8px;
#   overflow: hidden;
# }
# .loop-anim-header {
#   background: #0e1020;
#   padding: 8px 14px;
#   font-size: 10px;
#   color: var(--cyan);
#   letter-spacing: 2px;
#   text-transform: uppercase;
#   border-bottom: 1px solid var(--border);
#   display: flex;
#   justify-content: space-between;
#   align-items: center;
# }
# .loop-anim-body { padding: 18px; min-height: 160px; }
# .loop-code-line {
#   font-size: 12px;
#   line-height: 1.9;
#   padding: 2px 6px;
#   border-radius: 3px;
#   transition: all 0.2s;
# }
# .loop-code-line.hl {
#   background: rgba(77,255,144,0.1);
#   border-left: 2px solid var(--green);
#   padding-left: 4px;
# }
# .loop-code-line.dim { opacity: 0.3; }
# .kw { color: #c792ea; }
# .fn { color: #82aaff; }
# .str { color: #c3e88d; }
# .num { color: #f78c6c; }
# .cmt { color: #3a4060; font-style: italic; }
# .prop { color: #89ddff; }
# .loop-explain {
#   margin-top: 12px;
#   padding: 12px 14px;
#   background: rgba(77,255,144,0.05);
#   border: 1px solid rgba(77,255,144,0.15);
#   border-radius: 6px;
#   font-size: 12px;
#   line-height: 1.7;
#   color: var(--text);
# }
# .loop-explain strong { color: var(--green); }
#
# /* ── SECTION 3: Clicker internals ── */
# .clicker-layout {
#   display: grid;
#   grid-template-columns: 1fr 1fr;
#   gap: 20px;
# }
# .clicker-code {
#   background: #010306;
#   border: 1px solid var(--border);
#   border-radius: 8px;
#   overflow: hidden;
# }
# .clicker-code-header {
#   background: #0e1020;
#   padding: 7px 14px;
#   font-size: 10px;
#   color: var(--purple);
#   letter-spacing: 2px;
#   text-transform: uppercase;
#   border-bottom: 1px solid var(--border);
# }
# .clicker-code-body { padding: 14px; }
# .cc-line {
#   display: flex;
#   gap: 10px;
#   padding: 3px 5px;
#   border-radius: 3px;
#   cursor: pointer;
#   transition: all 0.15s;
#   font-size: 11.5px;
#   line-height: 1.7;
# }
# .cc-line:hover { background: rgba(199,146,234,0.06); }
# .cc-line.active { background: rgba(199,146,234,0.1); border-left: 2px solid var(--purple); padding-left: 3px; }
# .cc-line.dim { opacity: 0.3; }
# .cc-ln { color: #2e3860; font-size: 10px; min-width: 18px; padding-top: 2px; user-select: none; }
# .clicker-panels {
#   display: flex;
#   flex-direction: column;
#   gap: 8px;
# }
# .cp {
#   border: 1px solid var(--border);
#   border-radius: 6px;
#   overflow: hidden;
#   cursor: pointer;
#   transition: all 0.2s;
# }
# .cp:hover, .cp.active { border-color: var(--purple); }
# .cp-head {
#   display: flex;
#   align-items: center;
#   gap: 10px;
#   padding: 10px 14px;
#   font-size: 12px;
#   font-weight: 700;
# }
# .cp-icon { font-size: 16px; }
# .cp-name { color: #fff; flex: 1; }
# .cp-tag {
#   font-size: 9px;
#   padding: 2px 6px;
#   border-radius: 3px;
#   letter-spacing: 1px;
#   text-transform: uppercase;
# }
# .cp-body {
#   display: none;
#   padding: 12px 14px;
#   font-size: 12px;
#   line-height: 1.75;
#   color: var(--text);
#   border-top: 1px solid var(--border);
#   background: rgba(0,0,0,0.3);
# }
# .cp.active .cp-body { display: block; }
# .cp-body code { color: var(--cyan); font-size: 11px; }
# .cp-body strong { color: var(--purple); }
#
# /* ── SECTION 4: State model ── */
# .state-layout { display: grid; grid-template-columns: 1fr 1fr; gap: 20px; }
# .state-box {
#   background: #010306;
#   border: 1px solid var(--border);
#   border-radius: 8px;
#   overflow: hidden;
# }
# .state-box-head {
#   padding: 10px 14px;
#   font-size: 10px;
#   letter-spacing: 2px;
#   text-transform: uppercase;
#   border-bottom: 1px solid var(--border);
#   display: flex;
#   align-items: center;
#   gap: 8px;
# }
# .state-box-body { padding: 14px; font-size: 12px; line-height: 1.8; }
# .state-row {
#   display: flex;
#   align-items: flex-start;
#   gap: 10px;
#   padding: 7px 0;
#   border-bottom: 1px solid #0d1020;
# }
# .state-row:last-child { border-bottom: none; }
# .state-key { color: var(--cyan); min-width: 140px; font-size: 11px; }
# .state-val { color: var(--text); font-size: 11px; }
# .state-scope {
#   font-size: 10px;
#   padding: 2px 6px;
#   border-radius: 3px;
#   margin-left: auto;
#   flex-shrink: 0;
# }
# .scope-local { background: rgba(77,255,144,0.1); border: 1px solid rgba(77,255,144,0.3); color: var(--green); }
# .scope-shared { background: rgba(77,200,255,0.1); border: 1px solid rgba(77,200,255,0.3); color: var(--cyan); }
#
# /* ── SECTION 5: Level diff ── */
# .level-tabs { display: flex; gap: 6px; margin-bottom: 14px; }
# .ltab {
#   padding: 7px 16px;
#   border-radius: 5px;
#   border: 1px solid var(--border);
#   font-size: 11px;
#   font-weight: 700;
#   cursor: pointer;
#   transition: all 0.15s;
#   color: var(--dim);
# }
# .ltab:hover, .ltab.active {
#   border-color: var(--yellow);
#   color: var(--yellow);
#   background: rgba(255,204,77,0.07);
# }
# .level-panel { display: none; }
# .level-panel.active { display: block; }
# .level-diff {
#   display: grid;
#   grid-template-columns: 1fr 1fr;
#   gap: 16px;
# }
# .level-diff-code {
#   background: #010306;
#   border: 1px solid var(--border);
#   border-radius: 8px;
#   overflow: hidden;
# }
# .level-diff-header {
#   background: #0e1020;
#   padding: 7px 14px;
#   font-size: 10px;
#   color: var(--yellow);
#   letter-spacing: 2px;
#   text-transform: uppercase;
#   border-bottom: 1px solid var(--border);
# }
# .level-diff-body { padding: 14px; font-size: 11.5px; line-height: 1.85; }
# .diff-hl { background: rgba(255,204,77,0.12); border-radius: 2px; padding: 0 3px; color: var(--yellow); font-weight: 700; }
# .level-notes { }
# .level-note {
#   border-left: 2px solid var(--yellow);
#   padding: 10px 14px;
#   margin-bottom: 10px;
#   background: rgba(255,204,77,0.04);
#   border-radius: 0 6px 6px 0;
#   font-size: 12px;
#   line-height: 1.7;
# }
# .level-note strong { color: var(--yellow); display: block; margin-bottom: 4px; font-size: 11px; letter-spacing: 0.5px; }
# .lvl-badge {
#   display: inline-flex;
#   align-items: center;
#   gap: 6px;
#   font-size: 10px;
#   padding: 3px 8px;
#   border-radius: 3px;
#   margin-bottom: 12px;
#   letter-spacing: 1px;
#   text-transform: uppercase;
#   font-weight: 700;
# }
# .run-btn {
#   background: linear-gradient(180deg, #1e3a5f, #162d4a);
#   border: 1px solid #2a5080;
#   color: var(--cyan);
#   font-family: var(--mono);
#   font-size: 10px;
#   padding: 4px 10px;
#   border-radius: 4px;
#   cursor: pointer;
#   letter-spacing: 1px;
#   transition: all 0.15s;
# }
# .run-btn:hover { filter: brightness(1.3); }
# </style>
#
# <div class="garch">
#
# <!-- ═══ SECTION 1: Architecture Pipeline ═══ -->
# <div class="gs">
#   <div class="gs-title">Architecture — <span>How the Runner Connects Everything</span></div>
#   <div class="gs-sub">// click any node to inspect</div>
#   <div class="pipe" id="pipe">
#     <div class="pipe-node" onclick="pipeClick(0)" data-idx="0">
#       <div class="pipe-icon">📄</div>
#       <div class="pipe-label">Runner Cell</div>
#       <div class="pipe-file">%%js / gategame.ipynb</div>
#     </div>
#     <div class="pipe-node" onclick="pipeClick(1)" data-idx="1">
#       <div class="pipe-icon">🎮</div>
#       <div class="pipe-label">GameControl</div>
#       <div class="pipe-file">GameEnginev1.1/essentials/</div>
#     </div>
#     <div class="pipe-node" onclick="pipeClick(2)" data-idx="2">
#       <div class="pipe-icon">🗺️</div>
#       <div class="pipe-label">Level Classes</div>
#       <div class="pipe-file">gategame/levels/</div>
#     </div>
#     <div class="pipe-node" onclick="pipeClick(3)" data-idx="3">
#       <div class="pipe-icon">🖱️</div>
#       <div class="pipe-label">Clicker</div>
#       <div class="pipe-file">{ class, data } entry</div>
#     </div>
#     <div class="pipe-node" onclick="pipeClick(4)" data-idx="4">
#       <div class="pipe-icon">🌐</div>
#       <div class="pipe-label">gameEnv.stats</div>
#       <div class="pipe-file">shared context</div>
#     </div>
#   </div>
#   <div class="pipe-detail" id="pipe-detail">
#     ← Click a node above to see how it fits into the architecture.
#   </div>
# </div>
#
# <!-- ═══ SECTION 2: Game Loop ═══ -->
# <div class="gs">
#   <div class="gs-title">Game Loop — <span>Update &amp; Draw Cycle</span></div>
#   <div class="gs-sub">// requestAnimationFrame drives every frame — click a step to follow execution</div>
#   <div class="loop-wrap">
#     <div class="loop-steps" id="loop-steps">
#       <div class="loop-step active" onclick="loopClick(0)"><div class="loop-step-dot"></div>requestAnimationFrame</div>
#       <div class="loop-step" onclick="loopClick(1)"><div class="loop-step-dot"></div>GameControl.loop()</div>
#       <div class="loop-step" onclick="loopClick(2)"><div class="loop-step-dot"></div>object.update()</div>
#       <div class="loop-step" onclick="loopClick(3)"><div class="loop-step-dot"></div>object.draw()</div>
#       <div class="loop-step" onclick="loopClick(4)"><div class="loop-step-dot"></div>scheduleNext()</div>
#     </div>
#     <div class="loop-anim">
#       <div class="loop-anim-header">
#         <span>GameControl.js — core loop</span>
#         <button class="run-btn" onclick="loopAnimate()">▶ ANIMATE</button>
#       </div>
#       <div class="loop-anim-body" id="loop-body">
#         <div class="loop-code-line" id="lc0"><span class="kw">loop</span>() {</div>
#         <div class="loop-code-line" id="lc1">&nbsp;&nbsp;<span class="kw">for</span> (<span class="kw">const</span> obj <span class="kw">of</span> <span class="prop">this</span>.<span class="fn">objects</span>) {</div>
#         <div class="loop-code-line" id="lc2">&nbsp;&nbsp;&nbsp;&nbsp;obj.<span class="fn">update</span>();&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<span class="cmt">// physics, timer checks, state</span></div>
#         <div class="loop-code-line" id="lc3">&nbsp;&nbsp;&nbsp;&nbsp;obj.<span class="fn">draw</span>();&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<span class="cmt">// paint to canvas</span></div>
#         <div class="loop-code-line" id="lc4">&nbsp;&nbsp;}</div>
#         <div class="loop-code-line" id="lc5">&nbsp;&nbsp;<span class="fn">requestAnimationFrame</span>(<span class="prop">this</span>.<span class="fn">loop</span>.<span class="fn">bind</span>(<span class="prop">this</span>));</div>
#         <div class="loop-code-line" id="lc6">}</div>
#         <div class="loop-explain" id="loop-explain">
#           <strong>requestAnimationFrame</strong> — GameControl schedules itself to run on the next paint frame (~60fps). The loop is re-registered at the end of every call, keeping it alive until <code>destroy()</code> cancels the frame ID.
#         </div>
#       </div>
#     </div>
#   </div>
# </div>
#
# <!-- ═══ SECTION 3: Clicker Internals ═══ -->
# <div class="gs">
#   <div class="gs-title">Clicker Class — <span>Input → State → Reward</span></div>
#   <div class="gs-sub">// click a line to see what it does internally</div>
#   <div class="clicker-layout">
#     <div class="clicker-code">
#       <div class="clicker-code-header">interact() — the user-defined callback</div>
#       <div class="clicker-code-body" id="cc-body">
#         <div class="cc-line" id="ccl0" onclick="ccClick(0)"><span class="cc-ln">1</span><span><span class="fn">interact</span>: <span class="kw">function</span>(<span class="prop">clicks</span>) {</span></div>
#         <div class="cc-line" id="ccl1" onclick="ccClick(1)"><span class="cc-ln">2</span><span>&nbsp;&nbsp;<span class="kw">const</span> <span class="prop">CLICKS_PER_COIN</span> = <span class="num">3</span>;</span></div>
#         <div class="cc-line" id="ccl2" onclick="ccClick(2)"><span class="cc-ln">3</span><span>&nbsp;&nbsp;<span class="kw">const</span> <span class="prop">MAX_BONUS</span> = <span class="num">40</span>;</span></div>
#         <div class="cc-line" id="ccl3" onclick="ccClick(3)"><span class="cc-ln">4</span><span>&nbsp;&nbsp;<span class="kw">if</span> (<span class="kw">typeof</span> <span class="prop">this._bonusCoinsGiven</span> !== <span class="str">'number'</span>)</span></div>
#         <div class="cc-line" id="ccl4" onclick="ccClick(4)"><span class="cc-ln">5</span><span>&nbsp;&nbsp;&nbsp;&nbsp;<span class="prop">this._bonusCoinsGiven</span> = <span class="num">0</span>;</span></div>
#         <div class="cc-line" id="ccl5" onclick="ccClick(5)"><span class="cc-ln">6</span><span>&nbsp;&nbsp;<span class="kw">if</span> (<span class="prop">this._bonusCoinsGiven</span> >= <span class="prop">MAX_BONUS</span>) <span class="kw">return</span>;</span></div>
#         <div class="cc-line" id="ccl6" onclick="ccClick(6)"><span class="cc-ln">7</span><span>&nbsp;&nbsp;<span class="kw">if</span> (<span class="prop">clicks</span> % <span class="prop">CLICKS_PER_COIN</span> === <span class="num">0</span>) {</span></div>
#         <div class="cc-line" id="ccl7" onclick="ccClick(7)"><span class="cc-ln">8</span><span>&nbsp;&nbsp;&nbsp;&nbsp;<span class="prop">gameEnv</span>.<span class="prop">stats</span>.<span class="prop">coinsCollected</span>++;</span></div>
#         <div class="cc-line" id="ccl8" onclick="ccClick(8)"><span class="cc-ln">9</span><span>&nbsp;&nbsp;&nbsp;&nbsp;<span class="prop">this._bonusCoinsGiven</span>++;</span></div>
#         <div class="cc-line" id="ccl9" onclick="ccClick(9)"><span class="cc-ln">10</span><span>&nbsp;&nbsp;}</span></div>
#         <div class="cc-line" id="ccl10" onclick="ccClick(10)"><span class="cc-ln">11</span><span>}</span></div>
#       </div>
#     </div>
#     <div class="clicker-panels" id="cc-panels">
#       <div class="cp active" id="cp0">
#         <div class="cp-head"><span class="cp-icon">🎯</span><span class="cp-name">clicks parameter</span><span class="cp-tag scope-local">L1</span></div>
#         <div class="cp-body">Passed by the <code>Clicker</code> class after every confirmed canvas hit. It's a running total that increments on each click and only resets when the sprite repositions (Cannonball level) or when the level is torn down.</div>
#       </div>
#       <div class="cp" id="cp1" onclick="ccClick(1)">
#         <div class="cp-head"><span class="cp-icon">⚙️</span><span class="cp-name">CLICKS_PER_COIN</span><span class="cp-tag scope-local">L2</span></div>
#         <div class="cp-body">A local constant — the modulo gate threshold. Changing this is all you need to make rewards easier or harder. It never needs to be stored on the instance because it's read-only config.</div>
#       </div>
#       <div class="cp" id="cp3" onclick="ccClick(3)">
#         <div class="cp-head"><span class="cp-icon">🔧</span><span class="cp-name">Lazy state init</span><span class="cp-tag scope-local">L4–5</span></div>
#         <div class="cp-body"><code>_bonusCoinsGiven</code> lives on the data object itself. Because <code>interact</code> is a method on that object, <code>this</code> refers to the data object — so the counter survives across calls without any external storage.</div>
#       </div>
#       <div class="cp" id="cp5" onclick="ccClick(5)">
#         <div class="cp-head"><span class="cp-icon">🛑</span><span class="cp-name">Cap guard (early return)</span><span class="cp-tag scope-local">L6</span></div>
#         <div class="cp-body">Once the cap is reached, <code>interact()</code> becomes a no-op. The <code>Clicker</code> still registers hits and still increments <code>clicks</code> — the guard only prevents the reward branch from firing.</div>
#       </div>
#       <div class="cp" id="cp6" onclick="ccClick(6)">
#         <div class="cp-head"><span class="cp-icon">➗</span><span class="cp-name">Modulo gate</span><span class="cp-tag scope-local">L7</span></div>
#         <div class="cp-body"><code>clicks % N === 0</code> fires on every Nth hit. The <code>Clicker</code> class owns the counter; <code>interact()</code> only inspects it. This keeps the reward logic in the data object, not buried in the class.</div>
#       </div>
#       <div class="cp" id="cp7" onclick="ccClick(7)">
#         <div class="cp-head"><span class="cp-icon">🌐</span><span class="cp-name">gameEnv.stats write</span><span class="cp-tag scope-shared">SHARED</span></div>
#         <div class="cp-body"><code>gameEnv</code> is the cross-object context owned by <code>GameControl</code>. Writing to <code>stats.coinsCollected</code> here makes the score visible to the HUD, other objects, and the level-completion check — all without direct references between them.</div>
#       </div>
#     </div>
#   </div>
# </div>
#
# <!-- ═══ SECTION 4: State Model ═══ -->
# <div class="gs">
#   <div class="gs-title">State Management — <span>Instance vs Shared</span></div>
#   <div class="gs-sub">// two layers: per-object private state and the shared environment</div>
#   <div class="state-layout">
#     <div class="state-box">
#       <div class="state-box-head" style="background:rgba(77,255,144,0.06);color:var(--green);">
#         <span>🔒</span> Instance State — lives on <code style="font-size:10px">this</code> (data object)
#       </div>
#       <div class="state-box-body">
#         <div class="state-row">
#           <span class="state-key">_bonusCoinsGiven</span>
#           <span class="state-val">Reward counter, private to this Clicker. Persists across calls because <code>this</code> is the data object.</span>
#           <span class="state-scope scope-local">local</span>
#         </div>
#         <div class="state-row">
#           <span class="state-key">clicks (in Clicker class)</span>
#           <span class="state-val">Running click total. Owned by the <code>Clicker</code> class, not the data object. Resets on reposition.</span>
#           <span class="state-scope scope-local">local</span>
#         </div>
#         <div class="state-row">
#           <span class="state-key">INIT_POSITION, SCALE_FACTOR</span>
#           <span class="state-val">Read-only config. Set once in the data object, consumed during <code>draw()</code> but never mutated.</span>
#           <span class="state-scope scope-local">local</span>
#         </div>
#       </div>
#     </div>
#     <div class="state-box">
#       <div class="state-box-head" style="background:rgba(77,200,255,0.06);color:var(--cyan);">
#         <span>🌐</span> Shared State — lives on <code style="font-size:10px">gameEnv</code>
#       </div>
#       <div class="state-box-body">
#         <div class="state-row">
#           <span class="state-key">gameEnv.stats.coinsCollected</span>
#           <span class="state-val">Writable by any game object. Read by the HUD, the level-completion check, and the next level on load.</span>
#           <span class="state-scope scope-shared">shared</span>
#         </div>
#         <div class="state-row">
#           <span class="state-key">gameEnv.canvas / ctx</span>
#           <span class="state-val">The canvas element and 2D rendering context. All <code>draw()</code> calls target this. Replaced when the window resizes.</span>
#           <span class="state-scope scope-shared">shared</span>
#         </div>
#         <div class="state-row">
#           <span class="state-key">gameEnv.width / height</span>
#           <span class="state-val">Current canvas dimensions. Used for dynamic positioning (<code>width * 0.5</code>) at level construction time.</span>
#           <span class="state-scope scope-shared">shared</span>
#         </div>
#       </div>
#     </div>
#   </div>
# </div>
#
# <!-- ═══ SECTION 5: Level Configs ═══ -->
# <div class="gs">
#   <div class="gs-title">Level Configs — <span>What Actually Changes Per Level</span></div>
#   <div class="gs-sub">// same Clicker class, different data objects — switch levels to compare</div>
#   <div class="level-tabs">
#     <div class="ltab active" onclick="ltab(0)">🪙 Cannonball</div>
#     <div class="ltab" onclick="ltab(1)">🗝️ Escape Room</div>
#     <div class="ltab" onclick="ltab(2)">⚡ Zone Catch</div>
#   </div>
#
#   <!-- Cannonball -->
#   <div class="level-panel active" id="lp0">
#     <div class="lvl-badge" style="background:rgba(255,204,77,0.1);border:1px solid rgba(255,204,77,0.3);color:var(--yellow);">🪙 GameLevelCannonball</div>
#     <div class="level-diff">
#       <div class="level-diff-code">
#         <div class="level-diff-header">clickerData object</div>
#         <div class="level-diff-body">
# <span class="kw">const</span> clickerData = {<br>
# &nbsp;&nbsp;<span class="prop">id</span>: <span class="str">'BonusChest'</span>,<br>
# &nbsp;&nbsp;<span class="prop">src</span>: <span class="str">'images/.../coin.png'</span>,<br>
# &nbsp;&nbsp;<span class="prop">SCALE_FACTOR</span>: <span class="diff-hl">30</span>,<br>
# &nbsp;&nbsp;<span class="prop">INIT_POSITION</span>: { x: <span class="diff-hl">0.45</span>, y: <span class="diff-hl">0.30</span> },<br>
# &nbsp;&nbsp;<span class="cmt">// fractional coords → resolved to px by Clicker</span><br>
# &nbsp;&nbsp;<span class="fn">interact</span>(<span class="prop">clicks</span>) {<br>
# &nbsp;&nbsp;&nbsp;&nbsp;<span class="kw">const</span> <span class="prop">CLICKS_PER_COIN</span> = <span class="diff-hl">3</span>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp;<span class="kw">const</span> <span class="prop">MAX_BONUS</span> = <span class="diff-hl">40</span>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp;<span class="cmt">// ... guard + modulo gate</span><br>
# &nbsp;&nbsp;}<br>
# };<br><br>
# <span class="prop">this</span>.<span class="prop">classes</span> = [{ <span class="prop">class</span>: Clicker, <span class="prop">data</span>: clickerData }];
#         </div>
#       </div>
#       <div class="level-notes">
#         <div class="level-note"><strong>Fractional INIT_POSITION</strong>The <code>x: 0.45, y: 0.30</code> values are fractions of canvas size. <code>Clicker.draw()</code> multiplies these by <code>gameEnv.width/height</code> to get real pixel coordinates — so the sprite stays proportionally placed on any screen size.</div>
#         <div class="level-note"><strong>Periodic reposition</strong><code>Clicker.update()</code> runs a timer check every frame. After 2800ms, it picks a new random canvas position and resets its internal <code>clicks</code> counter to 0. The <code>interact</code> callback is not involved — the reset happens at the class level before <code>interact</code> is ever called again.</div>
#         <div class="level-note"><strong>No zIndex needed</strong>Cannonball is a single-layer level. <code>zIndex</code> is omitted, so the Clicker draws in document order — above the background, below nothing.</div>
#       </div>
#     </div>
#   </div>
#
#   <!-- Escape Room -->
#   <div class="level-panel" id="lp1">
#     <div class="lvl-badge" style="background:rgba(77,200,255,0.1);border:1px solid rgba(77,200,255,0.3);color:var(--cyan);">🗝️ GameLevelEscaperoom</div>
#     <div class="level-diff">
#       <div class="level-diff-code">
#         <div class="level-diff-header">treasureClickerData object</div>
#         <div class="level-diff-body">
# <span class="kw">const</span> treasureClickerData = {<br>
# &nbsp;&nbsp;<span class="prop">id</span>: <span class="str">'HiddenTreasure'</span>,<br>
# &nbsp;&nbsp;<span class="prop">src</span>: path + <span class="str">'/images/.../mastergate.png'</span>,<br>
# &nbsp;&nbsp;<span class="prop">SCALE_FACTOR</span>: <span class="diff-hl">22</span>,<br>
# &nbsp;&nbsp;<span class="prop">INIT_POSITION</span>: { x: <span class="diff-hl">340</span>, y: <span class="diff-hl">620</span> },<br>
# &nbsp;&nbsp;<span class="cmt">// absolute pixel coords — no reposition logic</span><br>
# &nbsp;&nbsp;<span class="prop">zIndex</span>: <span class="diff-hl">400</span>,<br>
# &nbsp;&nbsp;<span class="fn">interact</span>(<span class="prop">clicks</span>) {<br>
# &nbsp;&nbsp;&nbsp;&nbsp;<span class="kw">const</span> <span class="prop">CLICKS_PER_COIN</span> = <span class="diff-hl">3</span>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp;<span class="kw">const</span> <span class="prop">MAX_BONUS</span> = <span class="diff-hl">15</span>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp;<span class="cmt">// ... guard + modulo gate</span><br>
# &nbsp;&nbsp;}<br>
# };<br><br>
# <span class="prop">this</span>.<span class="prop">classes</span> = [{ <span class="prop">class</span>: Clicker, <span class="prop">data</span>: treasureClickerData }];
#         </div>
#       </div>
#       <div class="level-notes">
#         <div class="level-note"><strong>Absolute pixel INIT_POSITION</strong>Unlike Cannonball, this uses raw pixel values <code>{x:340, y:620}</code>. <code>Clicker</code> detects whether coords are fractional (≤1) or absolute and handles both. Tucked bottom-left means it's hidden until the player explores.</div>
#         <div class="level-note"><strong>zIndex: 400</strong>The Escape Room level stacks multiple layers (dungeon fog, walls, pickups). <code>zIndex</code> tells <code>GameControl</code>'s renderer to sort this object above fog layers so it's clickable once found, not buried under a fog layer's canvas region.</div>
#         <div class="level-note"><strong>No reposition timer</strong><code>update()</code> on a static Clicker is near-empty — just bounds checks. The sprite stays fixed for the level's lifetime, so <code>clicks</code> never resets mid-level.</div>
#       </div>
#     </div>
#   </div>
#
#   <!-- Zone Catch -->
#   <div class="level-panel" id="lp2">
#     <div class="lvl-badge" style="background:rgba(255,80,255,0.1);border:1px solid rgba(255,80,255,0.3);color:#ff80ff;">⚡ GameLevelZonecatch</div>
#     <div class="level-diff">
#       <div class="level-diff-code">
#         <div class="level-diff-header">powerCoreClickerData object</div>
#         <div class="level-diff-body">
# <span class="kw">const</span> powerCoreClickerData = {<br>
# &nbsp;&nbsp;<span class="prop">id</span>: <span class="str">'PowerCore'</span>,<br>
# &nbsp;&nbsp;<span class="prop">src</span>: path + <span class="str">'/images/.../mastergate.png'</span>,<br>
# &nbsp;&nbsp;<span class="prop">SCALE_FACTOR</span>: <span class="diff-hl">18</span>,<br>
# &nbsp;&nbsp;<span class="prop">INIT_POSITION</span>: {<br>
# &nbsp;&nbsp;&nbsp;&nbsp;x: <span class="diff-hl">Math.round(width * 0.5) - 64</span>,<br>
# &nbsp;&nbsp;&nbsp;&nbsp;y: <span class="diff-hl">Math.round(height * 0.12)</span><br>
# &nbsp;&nbsp;},<br>
# &nbsp;&nbsp;<span class="prop">zIndex</span>: <span class="diff-hl">400</span>,<br>
# &nbsp;&nbsp;<span class="fn">interact</span>(<span class="prop">clicks</span>) {<br>
# &nbsp;&nbsp;&nbsp;&nbsp;<span class="kw">const</span> <span class="prop">CLICKS_PER_COIN</span> = <span class="diff-hl">4</span>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp;<span class="kw">const</span> <span class="prop">MAX_BONUS</span> = <span class="diff-hl">20</span>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp;<span class="cmt">// ... guard + modulo gate</span><br>
# &nbsp;&nbsp;}<br>
# };<br><br>
# <span class="prop">this</span>.<span class="prop">classes</span> = [{ <span class="prop">class</span>: Clicker, <span class="prop">data</span>: powerCoreClickerData }];
#         </div>
#       </div>
#       <div class="level-notes">
#         <div class="level-note"><strong>Dynamic INIT_POSITION</strong><code>width</code> and <code>height</code> come from <code>gameEnv</code> at level construction time. The expression runs once when the Level class is instantiated — not every frame. This centers the sprite on whatever canvas size the browser reports at load.</div>
#         <div class="level-note"><strong>CLICKS_PER_COIN = 4</strong>This is the only difference in reward logic between levels. The Clicker class and <code>interact</code> body are identical — just the threshold constant changes. No subclassing needed.</div>
#         <div class="level-note"><strong>Adding a new object type</strong>To extend any level: implement <code>update()</code>, <code>draw()</code>, and <code>destroy()</code> on a new class, then push <code>{ class: YourClass, data: yourData }</code> into <code>this.classes</code>. GameControl handles the rest — instantiation, loop registration, and teardown.</div>
#       </div>
#     </div>
#   </div>
#
# </div>
# </div>
#
# <script>
# /* ── Pipeline ── */
# const pipeDetails = [
#   `<strong>Runner cell (%%js)</strong> — The entry point. Imports <code>GameControl</code> and the three level classes, then exports them so the page shell can instantiate the game. <code>gameLevelClasses</code> is an ordered array — GameControl works through it sequentially.`,
#   `<strong>GameControl</strong> — Owns the <code>requestAnimationFrame</code> loop, the <code>gameEnv</code> context object, and the level queue. On load it iterates <code>this.classes</code> from the active level and calls <code>new entry.class(entry.data, gameEnv)</code> for each. On level end it calls <code>destroy()</code> on all live objects and loads the next level.`,
#   `<strong>Level classes</strong> — Configuration containers. Each constructor builds <code>this.classes = [{ class, data }, ...]</code>. Adding a new interactive object to a level means adding one entry here — GameControl's instantiation loop picks it up automatically.`,
#   `<strong>Clicker</strong> — A generic interactive sprite. On construction it attaches a <code>click</code> listener to the canvas. Each confirmed hit increments an internal counter and calls <code>data.interact(clicks)</code>. The class owns input and timing; the data object owns reward logic.`,
#   `<strong>gameEnv.stats</strong> — The shared write target for any cross-object communication. Clicker writes <code>coinsCollected</code> here; the HUD reads it every frame from <code>draw()</code>; the level-completion check reads it too. No direct object-to-object references needed.`
# ];
# function pipeClick(idx) {
#   document.querySelectorAll('.pipe-node').forEach((n,i) => n.classList.toggle('active', i===idx));
#   document.getElementById('pipe-detail').innerHTML = pipeDetails[idx];
# }
#
# /* ── Loop ── */
# const loopExplains = [
#   `<strong>requestAnimationFrame</strong> — GameControl schedules itself to run on the next browser paint frame (~60fps). The loop is re-registered at the end of every call using <code>.bind(this)</code> to keep context. <code>GameControl.destroy()</code> cancels the pending frame ID to stop the loop.`,
#   `<strong>GameControl.loop()</strong> — The top-level tick. Before iterating objects it checks whether the current level is complete; if so it tears down and loads the next level class instead of running update/draw.`,
#   `<strong>object.update()</strong> — Called first every frame. Each object manages its own logic: Clicker checks its reposition timer, collision objects run AABB tests, the player reads keyboard state. No object talks to another directly — they all communicate through <code>gameEnv</code>.`,
#   `<strong>object.draw()</strong> — Called after all updates. Objects paint to <code>gameEnv.ctx</code> (the shared canvas 2D context). Draw order follows <code>zIndex</code> — GameControl sorts the objects array by <code>zIndex</code> before calling draw so layers stack correctly.`,
#   `<strong>scheduleNext</strong> — The final line of every loop call: <code>requestAnimationFrame(this.loop.bind(this))</code>. This keeps the loop alive and hands control back to the browser so it can handle layout, input, and other tabs between frames.`
# ];
# const loopHighlights = [[0,6],[0,6],[2,2],[3,3],[5,5]];
# function loopClick(idx) {
#   document.querySelectorAll('.loop-step').forEach((s,i) => s.classList.toggle('active', i===idx));
#   const lines = document.querySelectorAll('[id^="lc"]');
#   const [hl1, hl2] = loopHighlights[idx];
#   lines.forEach((l,i) => {
#     l.className = 'loop-code-line';
#     if (i >= hl1 && i <= hl2) l.classList.add('hl');
#     else l.classList.add('dim');
#   });
#   document.getElementById('loop-explain').innerHTML = loopExplains[idx];
# }
#
# let animTimer = null;
# function loopAnimate() {
#   let i = 0;
#   if (animTimer) clearInterval(animTimer);
#   animTimer = setInterval(() => { loopClick(i); i = (i+1)%5; }, 900);
# }
#
# /* ── Clicker code ── */
# const ccMap = {0:0, 1:1, 2:2, 3:3, 4:3, 5:4, 6:5, 7:6, 8:7, 9:8, 10:10};
# const ccPanels = [0,1,1,3,3,5,6,7,7,9,10];
# function ccClick(lineIdx) {
#   document.querySelectorAll('[id^="ccl"]').forEach((l,i) => {
#     l.className = 'cc-line' + (i===lineIdx ? ' active' : ' dim');
#   });
#   const pId = ['cp0','cp1','cp1','cp3','cp3','cp5','cp6','cp7','cp7','cp3','cp0'][lineIdx] || 'cp0';
#   document.querySelectorAll('.cp').forEach(p => {
#     p.classList.toggle('active', p.id === pId);
#     const b = p.querySelector('.cp-body');
#     if (b) b.style.display = p.classList.contains('active') ? 'block' : 'none';
#   });
# }
# // init panel visibility
# document.querySelectorAll('.cp-body').forEach((b,i) => { b.style.display = i===0 ? 'block' : 'none'; });
#
# /* ── Level tabs ── */
# function ltab(idx) {
#   document.querySelectorAll('.ltab').forEach((t,i) => t.classList.toggle('active', i===idx));
#   document.querySelectorAll('.level-panel').forEach((p,i) => p.classList.toggle('active', i===idx));
# }
# </script>
