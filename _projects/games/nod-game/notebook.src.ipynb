# %% [raw]
# ---
# layout: post
# title: NodCursor Maze Game
# description: A game where you control your character by moving your head! Turn on the Head Tracking in the Dashboard to play without your mouse.
# permalink: /nod-game
# codemirror: true
# hide: true
# toc: false
# ---

# %%
# %%js
#
# // GAME_RUNNER: Nod Tracker Game | hide_edit: true,  width: 100%, height: 500px
#
# import GameControl from '@assets/js/GameEnginev1.1/essentials/GameControl.js';
# import GameLevelNod from '@assets/js/projects/nod-game/levels/GameLevelNod.js';
#
# export const gameLevelClasses = [GameLevelNod];
# export { GameControl };

# %% [markdown]
# ### How to Play
#
# Enable the head-tracking accessibility feature on the OCS dashboard. You can follow instructions to calibrate the cursor for your head movements and save your calibration.
#
# Move your head around on this game and the circle will follow you.
#
# Avoid hitting the red walls. 5 hits and you have to restart!
#
# Complete all three levels to win.
#
# This game is an example for how NodCursor can be implemented in future games to improve accessibility across OCS.
